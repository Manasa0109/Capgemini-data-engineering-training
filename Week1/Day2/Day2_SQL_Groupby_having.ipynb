-- %%
CREATE TABLE Employee (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
department VARCHAR(50),
salary DECIMAL(10, 2),
joining_date DATE
);
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-6415374942482205>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE TABLE Employee (\nemp_id INT PRIMARY KEY,\nemp_name VARCHAR(50),\ndepartment VARCHAR(50),\nsalary DECIMAL(10, 2),\njoining_date DATE\n);\n')
--
-- File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
--    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
--
-- ...

-- %%
INSERT INTO Employee (emp_id, emp_name, department, salary, joining_date) VALUES
(1, 'Karthik', 'HR', 60000.00, '2021-01-15'),
(2, 'Pratik', 'Finance', 70000.00, '2021-03-10'),
(3, 'Veer', 'HR', 55000.00, '2021-06-20'),
(4, 'Priya', 'Finance', 80000.00, '2022-01-05'),
(5, 'Ajay', 'Engineering', 75000.00, '2020-11-01'),
(6, 'Vijay', 'Engineering', 78000.00, '2019-05-22'),
(7, 'Veena', 'HR', 62000.00, '2023-03-12'),
(8, 'Meena', 'Marketing', 65000.00, '2022-08-18');

-- %%
CREATE TABLE Sales (
sales_id INT PRIMARY KEY,
emp_id INT,
product VARCHAR(50),
amount DECIMAL(10, 2),
sale_date DATE
);
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-6415374942482208>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE TABLE Sales (\nsales_id INT PRIMARY KEY,\nemp_id INT,\nproduct VARCHAR(50),\namount DECIMAL(10, 2),\nsale_date DATE\n);\n')
--
-- File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
--    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
--
-- ...

-- %%
INSERT INTO Sales (sales_id, emp_id, product, amount, sale_date) VALUES
(1, 1, 'Laptop', 50000.00, '2023-01-15'),
(2, 2, 'Mobile', 30000.00, '2023-02-18'),
(3, 3, 'Tablet', 20000.00, '2023-02-25'),
(4, 4, 'Laptop', 45000.00, '2023-03-05'),
(5, 5, 'Mobile', 35000.00, '2023-03-12'),
(6, 6, 'Tablet', 25000.00, '2023-03-20'),
(7, 7, 'Laptop', 60000.00, '2023-04-01'),
(8, 8, 'Mobile', 40000.00, '2023-04-10');

-- %%
select * 
from employee
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
select *
from Sales
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
select department,sum(salary)
from Employee 
group by department
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>sum(salary)</th></tr></thead><tbody><tr><td>HR</td><td>177000.00</td></tr><tr><td>Finance</td><td>150000.00</td></tr><tr><td>Engineering</td><td>153000.00</td></tr><tr><td>Marketing</td><td>65000.00</td></tr></tbody></table></div>

-- %%
select count(*),department
from Employee 
group by department
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th><th>department</th></tr></thead><tbody><tr><td>3</td><td>HR</td></tr><tr><td>2</td><td>Finance</td></tr><tr><td>2</td><td>Engineering</td></tr><tr><td>1</td><td>Marketing</td></tr></tbody></table></div>

-- %%
select department,avg(salary)
from employee
group by department

-- %%
select department,max(salary)
from Employee 
group by department

-- %%
select department,min(salary)
from Employee 
group by department

-- %%
select department,sum(salary)
from Employee 
group by department
having sum(salary)>100000

-- %%
select department,count(*)
from employee
group by department
having count(*)>2

-- %%
select department,avg(salary)
from employee 
where joining_date>'2021-01-01'
group by department

-- %%
select department
from employee
group by department
having max(salary)>75000

-- %%
select department
from employee
group by department
having sum(salary) < 150000

-- %%
select department,count(*)
from employee
group by department
having count(*)>1

-- %%
select department,sum(salary)
from employee
group by department
having sum(salary)>125000

-- %%
select department,avg(salary)
from employee
group by department
having avg(salary)>60000

-- %%
select department,sum(salary)
from employee
group by department
having sum(salary) between 100000 and 200000

-- %%
select s.emp_id,e.emp_name,sum(amount)
from employee e inner join sales s
on e.emp_id=s.emp_id
group by s.emp_id,e.emp_name

-- %%
select s.emp_id,count(sales_id)
from employee e inner join sales s
on e.emp_id=s.emp_id
group by s.emp_id

-- %%
select product,avg(amount)
from sales
group by product
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>avg(amount)</th></tr></thead><tbody><tr><td>Laptop</td><td>51666.666667</td></tr><tr><td>Mobile</td><td>35000.000000</td></tr><tr><td>Tablet</td><td>22500.000000</td></tr></tbody></table></div>

-- %%
select emp_name,count(*)
from employee
group by emp_name
having count(*)>2
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>count(*)</th></tr></thead><tbody></tbody></table></div>

-- %%
select e.emp_id,sum(salary),sum(amount)
from employee e inner join sales s 
group by e.emp_id,s.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
select s.emp_id,count(distinct(product)) as distinct_products
from employee e inner join sales s 
group by s.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>distinct_products</th></tr></thead><tbody><tr><td>5</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>3</td><td>1</td></tr><tr><td>2</td><td>1</td></tr><tr><td>6</td><td>1</td></tr><tr><td>7</td><td>1</td></tr><tr><td>4</td><td>1</td></tr><tr><td>8</td><td>1</td></tr></tbody></table></div>

-- %%
select s.emp_id,max(amount)
from employee e inner join sales s
on e.emp_id=s.emp_id
group by s.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>max(amount)</th></tr></thead><tbody><tr><td>5</td><td>35000.00</td></tr><tr><td>1</td><td>50000.00</td></tr><tr><td>3</td><td>20000.00</td></tr><tr><td>2</td><td>30000.00</td></tr><tr><td>6</td><td>25000.00</td></tr><tr><td>7</td><td>60000.00</td></tr><tr><td>4</td><td>45000.00</td></tr><tr><td>8</td><td>40000.00</td></tr></tbody></table></div>

-- %%
select product,sum(amount)
from sales
group by product
having sum(amount)>50000
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>sum(amount)</th></tr></thead><tbody><tr><td>Laptop</td><td>155000.00</td></tr><tr><td>Mobile</td><td>105000.00</td></tr></tbody></table></div>

-- %%
select department,avg(amount)
from employee e inner join sales s 
on e.emp_id=s.emp_id
group by department
order by avg(amount) desc
limit 1
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>avg(amount)</th></tr></thead><tbody><tr><td>HR</td><td>43333.333333</td></tr></tbody></table></div>

-- %%
select department,sum(amount)
from employee  inner join sales 
on employee.emp_id=sales.emp_id
group by department
order by sum(amount) desc
limit 1
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>sum(amount)</th></tr></thead><tbody><tr><td>HR</td><td>130000.00</td></tr></tbody></table></div>

-- %%
select e.emp_name,sum(amount)
from employee e inner join sales s
group by e.emp_name,s.emp_id
order by sum(amount) desc
limit 3
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>sum(amount)</th></tr></thead><tbody><tr><td>Veer</td><td>60000.00</td></tr><tr><td>Vijay</td><td>60000.00</td></tr><tr><td>Priya</td><td>60000.00</td></tr></tbody></table></div>

-- %%
select year(joining_date),avg(salary),count(*)
from employee
group by year(joining_date)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year(joining_date)</th><th>avg(salary)</th><th>count(*)</th></tr></thead><tbody><tr><td>2021</td><td>61666.666667</td><td>3</td></tr><tr><td>2022</td><td>72500.000000</td><td>2</td></tr><tr><td>2020</td><td>75000.000000</td><td>1</td></tr><tr><td>2019</td><td>78000.000000</td><td>1</td></tr><tr><td>2023</td><td>62000.000000</td><td>1</td></tr></tbody></table></div>

-- %%
select department,sum(amount)
from employee e inner join sales s 
on e.emp_id=s.emp_id
group by department
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>sum(amount)</th></tr></thead><tbody><tr><td>Engineering</td><td>60000.00</td></tr><tr><td>HR</td><td>130000.00</td></tr><tr><td>Finance</td><td>75000.00</td></tr><tr><td>Marketing</td><td>40000.00</td></tr></tbody></table></div>

-- %%
select e.emp_id,e.department
from employee e left join sales s 
on e.emp_id=s.emp_id
where s.sales_id is null
group by e.department,e.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>department</th></tr></thead><tbody></tbody></table></div>
